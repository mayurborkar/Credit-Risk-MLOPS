# %%
import pandas as pd

# %%
data = pd.read_csv("../data_given/credit.csv")
data.drop(['Unnamed: 0'], axis=1, inplace =True)

# %%
data.columns
# Out:
# Index(['status', 'duration', 'credit_history', 'purpose', 'amount', 'savings',
#        'employment_duration', 'installment_rate', 'personal_status_sex',
#        'other_debtors', 'present_residence', 'property', 'age',
#        'other_installment_plans', 'housing', 'number_credits', 'job',
#        'people_liable', 'telephone', 'foreign_worker', 'credit_risk'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                           count      mean          std    min     25%     50%  \
# status                   1000.0     2.577     1.257638    1.0     1.0     2.0
# duration                 1000.0    20.903    12.058814    4.0    12.0    18.0
# credit_history           1000.0     2.545     1.083120    0.0     2.0     2.0
# purpose                  1000.0     2.828     2.744439    0.0     1.0     2.0
# amount                   1000.0  3271.248  2822.751760  250.0  1365.5  2319.5
# savings                  1000.0     2.105     1.580023    1.0     1.0     1.0
# employment_duration      1000.0     3.384     1.208306    1.0     3.0     3.0
# installment_rate         1000.0     2.973     1.118715    1.0     2.0     3.0
# personal_status_sex      1000.0     2.682     0.708080    1.0     2.0     3.0
# other_debtors            1000.0     1.145     0.477706    1.0     1.0     1.0
# present_residence        1000.0     2.845     1.103718    1.0     2.0     3.0
# property                 1000.0     2.358     1.050209    1.0     1.0     2.0
# age                      1000.0    35.542    11.352670   19.0    27.0    33.0
# other_installment_plans  1000.0     2.675     0.705601    1.0     3.0     3.0
# housing                  1000.0     1.928     0.530186    1.0     2.0     2.0
# number_credits           1000.0     1.407     0.577654    1.0     1.0     1.0
# job                      1000.0     2.904     0.653614    1.0     3.0     3.0
# people_liable            1000.0     1.845     0.362086    1.0     2.0     2.0
# telephone                1000.0     1.404     0.490943    1.0     1.0     1.0
# foreign_worker           1000.0     1.963     0.188856    1.0     2.0     2.0
# credit_risk              1000.0     0.700     0.458487    0.0     0.0     1.0
#
#                              75%      max
# status                      4.00      4.0
# duration                   24.00     72.0
# credit_history              4.00      4.0
# purpose                     3.00     10.0
# amount                   3972.25  18424.0
# savings                     3.00      5.0
# employment_duration         5.00      5.0
# installment_rate            4.00      4.0
# personal_status_sex         3.00      4.0
# other_debtors               1.00      3.0
# present_residence           4.00      4.0
# property                    3.00      4.0
# age                        42.00     75.0
# other_installment_plans     3.00      3.0
# housing                     2.00      3.0
# number_credits              2.00      4.0
# job                         3.00      4.0
# people_liable               2.00      2.0
# telephone                   2.00      2.0
# foreign_worker              2.00      2.0
# credit_risk                 1.00      1.0

# %%
overview = data.describe()

# %%
overview.loc[["min", "max"]].to_json("schema_in.json")

# %%
class NotInRange(Exception):
    def __init__(self, message="Value Not In Range"):
        self.message = message
        super().__init__(self.message)

# %%
raise NotInRange
# Out:
# ---------------------------------------------------------------------------
# NotInRange                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12568/749905967.py in <module>
# ----> 1 raise NotInRange
#
# NotInRange: Value Not In Range
